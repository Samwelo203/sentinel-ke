# %% [markdown]
# <a href="https://colab.research.google.com/github/Samwelo203/sentinel-ke/blob/main/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("sentinel-ke setup complete")
# Out:
# sentinel-ke setup complete
